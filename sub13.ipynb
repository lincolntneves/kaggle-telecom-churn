# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_predict
from sklearn.linear_model import LogisticRegression

# %%
## Dimensões para visualização de datasets
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.float_format', '{:.8f}'.format)

# %%
train = pd.read_csv('train.csv')
train.head()
# Out:
#    id  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou last_date_of_month_6 last_date_of_month_7 last_date_of_month_8       arpu_6       arpu_7       arpu_8  onnet_mou_6  onnet_mou_7  onnet_mou_8  offnet_mou_6  offnet_mou_7  offnet_mou_8  roam_ic_mou_6  roam_ic_mou_7  roam_ic_mou_8  roam_og_mou_6  roam_og_mou_7  roam_og_mou_8  loc_og_t2t_mou_6  loc_og_t2t_mou_7  loc_og_t2t_mou_8  loc_og_t2m_mou_6  loc_og_t2m_mou_7  loc_og_t2m_mou_8  loc_og_t2f_mou_6  loc_og_t2f_mou_7  loc_og_t2f_mou_8  loc_og_t2c_mou_6  loc_og_t2c_mou_7  loc_og_t2c_mou_8  loc_og_mou_6  loc_og_mou_7  loc_og_mou_8  std_og_t2t_mou_6  std_og_t2t_mou_7  std_og_t2t_mou_8  std_og_t2m_mou_6  std_og_t2m_mou_7  std_og_t2m_mou_8  std_og_t2f_mou_6  std_og_t2f_mou_7  std_og_t2f_mou_8  std_og_t2c_mou_6  std_og_t2c_mou_7  std_og_t2c_mou_8  std_og_mou_6  std_og_mou_7  std_og_mou_8  isd_og_mou_6  isd_og_mou_7  isd_og_mou_8  spl_og_mou_6  spl_og_mou_7  spl_og_mou_8  og_others_6  og_others_7  og_others_8  total_og_mou_6  \
# ...

# %%
features_names_BigMissing = ["total_rech_data_6",
"max_rech_data_6",
"count_rech_2g_6",
"count_rech_3g_6",
"av_rech_amt_data_6",
"arpu_3g_6",
"arpu_2g_6",
"night_pck_user_6",
"fb_user_6",
"total_rech_data_7",
"max_rech_data_7",
"count_rech_2g_7",
"count_rech_3g_7",
"av_rech_amt_data_7",
"arpu_3g_7",
"arpu_2g_7",
"night_pck_user_7",
"fb_user_7",
"total_rech_data_8",
"max_rech_data_8",
"count_rech_2g_8",
"count_rech_3g_8",
"av_rech_amt_data_8",
"arpu_3g_8",
"arpu_2g_8",
"night_pck_user_8",
"fb_user_8"]

# %%
# Using variables with less than 10% of missing values
features_names_LessMissing = ["onnet_mou_8",
"offnet_mou_8",
"roam_ic_mou_8",
"roam_og_mou_8",
"loc_og_t2t_mou_8",
"loc_og_t2m_mou_8",
"loc_og_t2f_mou_8",
"loc_og_t2c_mou_8",
"loc_og_mou_8",
"std_og_t2t_mou_8",
"std_og_t2m_mou_8",
"std_og_t2f_mou_8",
"std_og_t2c_mou_8",
"std_og_mou_8",
"isd_og_mou_8",
"spl_og_mou_8",
"og_others_8",
"loc_ic_t2t_mou_8",
"loc_ic_t2m_mou_8",
"loc_ic_t2f_mou_8",
"loc_ic_mou_8",
"std_ic_t2t_mou_8",
"std_ic_t2m_mou_8",
"std_ic_t2f_mou_8",
"std_ic_t2o_mou_8",
"std_ic_mou_8",
"spl_ic_mou_8",
"isd_ic_mou_8",
"ic_others_8",
"onnet_mou_6",
"offnet_mou_6",
"roam_ic_mou_6",
"roam_og_mou_6",
"loc_og_t2t_mou_6",
"loc_og_t2m_mou_6",
"loc_og_t2f_mou_6",
"loc_og_t2c_mou_6",
"loc_og_mou_6",
"std_og_t2t_mou_6",
"std_og_t2m_mou_6",
"std_og_t2f_mou_6",
"std_og_t2c_mou_6",
"std_og_mou_6",
"isd_og_mou_6",
"spl_og_mou_6",
"og_others_6",
"loc_ic_t2t_mou_6",
"loc_ic_t2m_mou_6",
"loc_ic_t2f_mou_6",
"loc_ic_mou_6",
"std_ic_t2t_mou_6",
"std_ic_t2m_mou_6",
"std_ic_t2f_mou_6",
"std_ic_t2o_mou_6",
"std_ic_mou_6",
"spl_ic_mou_6",
"isd_ic_mou_6",
"ic_others_6",
"onnet_mou_7",
"offnet_mou_7",
"roam_ic_mou_7",
"roam_og_mou_7",
"loc_og_t2t_mou_7",
"loc_og_t2m_mou_7",
"loc_og_t2f_mou_7",
"loc_og_t2c_mou_7",
"loc_og_mou_7",
"std_og_t2t_mou_7",
"std_og_t2m_mou_7",
"std_og_t2f_mou_7",
"std_og_t2c_mou_7",
"std_og_mou_7",
"isd_og_mou_7",
"spl_og_mou_7",
"og_others_7",
"loc_ic_t2t_mou_7",
"loc_ic_t2m_mou_7",
"loc_ic_t2f_mou_7",
"loc_ic_mou_7",
"std_ic_t2t_mou_7",
"std_ic_t2m_mou_7",
"std_ic_t2f_mou_7",
"std_ic_t2o_mou_7",
"std_ic_mou_7",
"spl_ic_mou_7",
"isd_ic_mou_7",
"ic_others_7",
"loc_og_t2o_mou",
"std_og_t2o_mou",
"loc_ic_t2o_mou",
"arpu_6",
"arpu_7",
"arpu_8",
"total_og_mou_6",
"total_og_mou_7",
"total_og_mou_8",
"total_ic_mou_6",
"total_ic_mou_7",
"total_ic_mou_8",
"total_rech_num_6",
"total_rech_num_7",
"total_rech_num_8",
"total_rech_amt_6",
"total_rech_amt_7",
"total_rech_amt_8",
"max_rech_amt_6",
"max_rech_amt_7",
"max_rech_amt_8",
"last_day_rch_amt_6",
"last_day_rch_amt_7",
"last_day_rch_amt_8",
"vol_2g_mb_6",
"vol_2g_mb_7",
"vol_2g_mb_8",
"vol_3g_mb_6",
"vol_3g_mb_7",
"vol_3g_mb_8",
"monthly_2g_6",
"monthly_2g_7",
"monthly_2g_8",
"sachet_2g_6",
"sachet_2g_7",
"sachet_2g_8",
"monthly_3g_6",
"monthly_3g_7",
"monthly_3g_8",
"sachet_3g_6",
"sachet_3g_7",
"sachet_3g_8",
"aon",
"aug_vbc_3g",
"jul_vbc_3g",
"jun_vbc_3g"]

# %%
X_train1 = train.set_index('id')[features_names_LessMissing].fillna(train.median())
X_train1.head()
# Out:
#     onnet_mou_8  offnet_mou_8  roam_ic_mou_8  roam_og_mou_8  loc_og_t2t_mou_8  loc_og_t2m_mou_8  loc_og_t2f_mou_8  loc_og_t2c_mou_8  loc_og_mou_8  std_og_t2t_mou_8  std_og_t2m_mou_8  std_og_t2f_mou_8  std_og_t2c_mou_8  std_og_mou_8  isd_og_mou_8  spl_og_mou_8  og_others_8  loc_ic_t2t_mou_8  loc_ic_t2m_mou_8  loc_ic_t2f_mou_8  loc_ic_mou_8  std_ic_t2t_mou_8  std_ic_t2m_mou_8  std_ic_t2f_mou_8  std_ic_t2o_mou_8  std_ic_mou_8  spl_ic_mou_8  isd_ic_mou_8  ic_others_8  onnet_mou_6  offnet_mou_6  roam_ic_mou_6  roam_og_mou_6  loc_og_t2t_mou_6  loc_og_t2m_mou_6  loc_og_t2f_mou_6  loc_og_t2c_mou_6  loc_og_mou_6  std_og_t2t_mou_6  std_og_t2m_mou_6  std_og_t2f_mou_6  std_og_t2c_mou_6  std_og_mou_6  isd_og_mou_6  spl_og_mou_6  og_others_6  loc_ic_t2t_mou_6  loc_ic_t2m_mou_6  loc_ic_t2f_mou_6  loc_ic_mou_6  std_ic_t2t_mou_6  std_ic_t2m_mou_6  std_ic_t2f_mou_6  std_ic_t2o_mou_6  std_ic_mou_6  spl_ic_mou_6  isd_ic_mou_6  ic_others_6  onnet_mou_7  offnet_mou_7  roam_ic_mou_7  roam_og_mou_7  \
# id
# ...

# %%
X_train2 = train.set_index('id')[features_names_BigMissing].fillna(train.mean())
X_train2.head()
# Out:
#     total_rech_data_6  max_rech_data_6  count_rech_2g_6  count_rech_3g_6  av_rech_amt_data_6   arpu_3g_6   arpu_2g_6  night_pck_user_6  fb_user_6  total_rech_data_7  max_rech_data_7  count_rech_2g_7  count_rech_3g_7  av_rech_amt_data_7    arpu_3g_7    arpu_2g_7  night_pck_user_7  fb_user_7  total_rech_data_8  max_rech_data_8  count_rech_2g_8  count_rech_3g_8  av_rech_amt_data_8   arpu_3g_8   arpu_2g_8  night_pck_user_8  fb_user_8
# id
# 0          2.46761157     126.50000000       1.86532332       0.60228825        192.83109574 90.06993112 86.86390027        0.02527322 0.91632514         2.67998880     126.40207109       2.05631122       0.62367758        201.45594011  89.11576714  85.84607445        0.02406941 0.90954380         2.65244068     125.37492534       2.01601781       0.63642287        196.81579247 90.61856437 86.34840365        0.02101319 0.89031873
# ...

# %%
X_train = pd.concat([X_train1,X_train2], axis=1)
X_train.head()
# Out:
#     onnet_mou_8  offnet_mou_8  roam_ic_mou_8  roam_og_mou_8  loc_og_t2t_mou_8  loc_og_t2m_mou_8  loc_og_t2f_mou_8  loc_og_t2c_mou_8  loc_og_mou_8  std_og_t2t_mou_8  std_og_t2m_mou_8  std_og_t2f_mou_8  std_og_t2c_mou_8  std_og_mou_8  isd_og_mou_8  spl_og_mou_8  og_others_8  loc_ic_t2t_mou_8  loc_ic_t2m_mou_8  loc_ic_t2f_mou_8  loc_ic_mou_8  std_ic_t2t_mou_8  std_ic_t2m_mou_8  std_ic_t2f_mou_8  std_ic_t2o_mou_8  std_ic_mou_8  spl_ic_mou_8  isd_ic_mou_8  ic_others_8  onnet_mou_6  offnet_mou_6  roam_ic_mou_6  roam_og_mou_6  loc_og_t2t_mou_6  loc_og_t2m_mou_6  loc_og_t2f_mou_6  loc_og_t2c_mou_6  loc_og_mou_6  std_og_t2t_mou_6  std_og_t2m_mou_6  std_og_t2f_mou_6  std_og_t2c_mou_6  std_og_mou_6  isd_og_mou_6  spl_og_mou_6  og_others_6  loc_ic_t2t_mou_6  loc_ic_t2m_mou_6  loc_ic_t2f_mou_6  loc_ic_mou_6  std_ic_t2t_mou_6  std_ic_t2m_mou_6  std_ic_t2f_mou_6  std_ic_t2o_mou_6  std_ic_mou_6  spl_ic_mou_6  isd_ic_mou_6  ic_others_6  onnet_mou_7  offnet_mou_7  roam_ic_mou_7  roam_og_mou_7  \
# id
# ...

# %%
X_train['arpu_2g_mean'] = (X_train.arpu_2g_6 + X_train.arpu_2g_7 + X_train.arpu_2g_8) / 3
X_train['arpu_3g_mean'] = (X_train.arpu_3g_6 + X_train.arpu_3g_7 + X_train.arpu_3g_8) / 3
X_train['arpu_mean'] = (X_train.arpu_6 + X_train.arpu_7 + X_train.arpu_8) / 3
X_train['av_rech_amt_data_mean'] = (X_train.av_rech_amt_data_6 + X_train.av_rech_amt_data_7 + X_train.av_rech_amt_data_8) / 3
X_train['count_rech_2g_mean'] = (X_train.count_rech_2g_6 + X_train.count_rech_2g_7 + X_train.count_rech_2g_8) / 3
X_train['count_rech_3g_mean'] = (X_train.count_rech_3g_6 + X_train.count_rech_3g_7 + X_train.count_rech_3g_8) / 3
X_train['fb_user_mean'] = (X_train.fb_user_6 + X_train.fb_user_7 + X_train.fb_user_8) / 3
X_train['ic_others_mean'] = (X_train.ic_others_6 + X_train.ic_others_7 + X_train.ic_others_8) / 3
X_train['isd_ic_mou_mean'] = (X_train.isd_ic_mou_6 + X_train.isd_ic_mou_7 + X_train.isd_ic_mou_8) / 3
X_train['isd_og_mou_mean'] = (X_train.isd_og_mou_6 + X_train.isd_og_mou_7 + X_train.isd_og_mou_8) / 3
X_train['vbc_3g_mean'] = (X_train.jul_vbc_3g + X_train.jun_vbc_3g ) / 2
X_train['last_day_rch_amt_mean'] = (X_train.last_day_rch_amt_6 + X_train.last_day_rch_amt_7 + X_train.last_day_rch_amt_8) / 3
X_train['loc_ic_mou_mean'] = (X_train.loc_ic_mou_6 + X_train.loc_ic_mou_7 + X_train.loc_ic_mou_8) / 3
X_train['loc_ic_t2f_mou_mean'] = (X_train.loc_ic_t2f_mou_6 + X_train.loc_ic_t2f_mou_7 + X_train.loc_ic_t2f_mou_8) / 3
X_train['loc_ic_t2m_mou_mean'] = (X_train.loc_ic_t2m_mou_6 + X_train.loc_ic_t2m_mou_7 + X_train.loc_ic_t2m_mou_8) / 3
X_train['loc_ic_t2t_mou_mean'] = (X_train.loc_ic_t2t_mou_6 + X_train.loc_ic_t2t_mou_7 + X_train.loc_ic_t2t_mou_8) / 3
X_train['loc_og_mou_mean'] = (X_train.loc_og_mou_6 + X_train.loc_og_mou_7 + X_train.loc_og_mou_8) / 3
X_train['loc_og_t2c_mou_mean'] = (X_train.loc_og_t2c_mou_6 + X_train.loc_og_t2c_mou_7 + X_train.loc_og_t2c_mou_8) / 3
X_train['loc_og_t2f_mou_mean'] = (X_train.loc_og_t2f_mou_6 + X_train.loc_og_t2f_mou_7 + X_train.loc_og_t2f_mou_8) / 3
X_train['loc_og_t2m_mou_mean'] = (X_train.loc_og_t2m_mou_6 + X_train.loc_og_t2m_mou_7 + X_train.loc_og_t2m_mou_8) / 3
X_train['loc_og_t2t_mou_mean'] = (X_train.loc_og_t2t_mou_6 + X_train.loc_og_t2t_mou_7 + X_train.loc_og_t2t_mou_8) / 3
X_train['max_rech_amt_mean'] = (X_train.max_rech_amt_6 + X_train.max_rech_amt_7 + X_train.max_rech_amt_8) / 3
X_train['max_rech_data_mean'] = (X_train.max_rech_data_6 + X_train.max_rech_data_7 + X_train.max_rech_data_8) / 3
X_train['monthly_2g_mean'] = (X_train.monthly_2g_6 + X_train.monthly_2g_7 + X_train.monthly_2g_8) / 3
X_train['monthly_3g_mean'] = (X_train.monthly_3g_6 + X_train.monthly_3g_7 + X_train.monthly_3g_8) / 3
X_train['night_pck_user_mean'] = (X_train.night_pck_user_6 + X_train.night_pck_user_7 + X_train.night_pck_user_8) / 3
X_train['offnet_mou_mean'] = (X_train.offnet_mou_6 + X_train.offnet_mou_7 + X_train.offnet_mou_8) / 3
X_train['og_others_mean'] = (X_train.og_others_6 + X_train.og_others_7 + X_train.og_others_8) / 3
X_train['onnet_mou_mean'] = (X_train.onnet_mou_6 + X_train.onnet_mou_7 + X_train.onnet_mou_8) / 3
X_train['roam_ic_mou_mean'] = (X_train.roam_ic_mou_6 + X_train.roam_ic_mou_7 + X_train.roam_ic_mou_8) / 3
X_train['roam_og_mou_mean'] = (X_train.roam_og_mou_6 + X_train.roam_og_mou_7 + X_train.roam_og_mou_8) / 3
X_train['sachet_2g_mean'] = (X_train.sachet_2g_6 + X_train.sachet_2g_7 + X_train.sachet_2g_8) / 3
X_train['sachet_3g_mean'] = (X_train.sachet_3g_6 + X_train.sachet_3g_7 + X_train.sachet_3g_8) / 3
X_train['spl_ic_mou_mean'] = (X_train.spl_ic_mou_6 + X_train.spl_ic_mou_7 + X_train.spl_ic_mou_8) / 3
X_train['spl_og_mou_mean'] = (X_train.spl_og_mou_6 + X_train.spl_og_mou_7 + X_train.spl_og_mou_8) / 3
X_train['std_ic_mou_mean'] = (X_train.std_ic_mou_6 + X_train.std_ic_mou_7 + X_train.std_ic_mou_8) / 3
X_train['std_ic_t2f_mou_mean'] = (X_train.std_ic_t2f_mou_6 + X_train.std_ic_t2f_mou_7 + X_train.std_ic_t2f_mou_8) / 3
X_train['std_ic_t2m_mou_mean'] = (X_train.std_ic_t2m_mou_6 + X_train.std_ic_t2m_mou_7 + X_train.std_ic_t2m_mou_8) / 3
X_train['std_ic_t2o_mou_mean'] = (X_train.std_ic_t2o_mou_6 + X_train.std_ic_t2o_mou_7 + X_train.std_ic_t2o_mou_8) / 3
X_train['std_ic_t2t_mou_mean'] = (X_train.std_ic_t2t_mou_6 + X_train.std_ic_t2t_mou_7 + X_train.std_ic_t2t_mou_8) / 3
X_train['std_og_mou_mean'] = (X_train.std_og_mou_6 + X_train.std_og_mou_7 + X_train.std_og_mou_8) / 3
X_train['std_og_t2c_mou_mean'] = (X_train.std_og_t2c_mou_6 + X_train.std_og_t2c_mou_7 + X_train.std_og_t2c_mou_8) / 3
X_train['std_og_t2f_mou_mean'] = (X_train.std_og_t2f_mou_6 + X_train.std_og_t2f_mou_7 + X_train.std_og_t2f_mou_8) / 3
X_train['std_og_t2m_mou_mean'] = (X_train.std_og_t2m_mou_6 + X_train.std_og_t2m_mou_7 + X_train.std_og_t2m_mou_8) / 3
X_train['std_og_t2t_mou_mean'] = (X_train.std_og_t2t_mou_6 + X_train.std_og_t2t_mou_7 + X_train.std_og_t2t_mou_8) / 3
X_train['total_ic_mou_mean'] = (X_train.total_ic_mou_6 + X_train.total_ic_mou_7 + X_train.total_ic_mou_8) / 3
X_train['total_og_mou_mean'] = (X_train.total_og_mou_6 + X_train.total_og_mou_7 + X_train.total_og_mou_8) / 3
X_train['total_rech_amt_mean'] = (X_train.total_rech_amt_6 + X_train.total_rech_amt_7 + X_train.total_rech_amt_8) / 3
X_train['total_rech_data_mean'] = (X_train.total_rech_data_6 + X_train.total_rech_data_7 + X_train.total_rech_data_8) / 3
X_train['total_rech_num_mean'] = (X_train.total_rech_num_6 + X_train.total_rech_num_7 + X_train.total_rech_num_8) / 3
X_train['vol_2g_mb_mean'] = (X_train.vol_2g_mb_6 + X_train.vol_2g_mb_7 + X_train.vol_2g_mb_8) / 3
X_train['vol_3g_mb_mean'] = (X_train.vol_3g_mb_6 + X_train.vol_3g_mb_7 + X_train.vol_3g_mb_8) / 3

# %%
X_train.head()
# Out:
#     onnet_mou_8  offnet_mou_8  roam_ic_mou_8  roam_og_mou_8  loc_og_t2t_mou_8  loc_og_t2m_mou_8  loc_og_t2f_mou_8  loc_og_t2c_mou_8  loc_og_mou_8  std_og_t2t_mou_8  std_og_t2m_mou_8  std_og_t2f_mou_8  std_og_t2c_mou_8  std_og_mou_8  isd_og_mou_8  spl_og_mou_8  og_others_8  loc_ic_t2t_mou_8  loc_ic_t2m_mou_8  loc_ic_t2f_mou_8  loc_ic_mou_8  std_ic_t2t_mou_8  std_ic_t2m_mou_8  std_ic_t2f_mou_8  std_ic_t2o_mou_8  std_ic_mou_8  spl_ic_mou_8  isd_ic_mou_8  ic_others_8  onnet_mou_6  offnet_mou_6  roam_ic_mou_6  roam_og_mou_6  loc_og_t2t_mou_6  loc_og_t2m_mou_6  loc_og_t2f_mou_6  loc_og_t2c_mou_6  loc_og_mou_6  std_og_t2t_mou_6  std_og_t2m_mou_6  std_og_t2f_mou_6  std_og_t2c_mou_6  std_og_mou_6  isd_og_mou_6  spl_og_mou_6  og_others_6  loc_ic_t2t_mou_6  loc_ic_t2m_mou_6  loc_ic_t2f_mou_6  loc_ic_mou_6  std_ic_t2t_mou_6  std_ic_t2m_mou_6  std_ic_t2f_mou_6  std_ic_t2o_mou_6  std_ic_mou_6  spl_ic_mou_6  isd_ic_mou_6  ic_others_6  onnet_mou_7  offnet_mou_7  roam_ic_mou_7  roam_og_mou_7  \
# id
# ...

# %%
feature_names = ["arpu_2g_mean",
"arpu_3g_mean",
"arpu_mean",
"aug_vbc_3g",
"av_rech_amt_data_mean",
"count_rech_2g_mean",
"count_rech_3g_mean",
"fb_user_mean",
"ic_others_mean",
"isd_ic_mou_mean",
"isd_og_mou_mean",
"vbc_3g_mean",
"last_day_rch_amt_mean",
"loc_ic_mou_mean",
"loc_ic_t2f_mou_mean",
"loc_ic_t2m_mou_mean",
"loc_ic_t2o_mou",
"loc_ic_t2t_mou_mean",
"loc_og_mou_mean",
"loc_og_t2c_mou_mean",
"loc_og_t2f_mou_mean",
"loc_og_t2m_mou_mean",
"loc_og_t2o_mou",
"loc_og_t2t_mou_mean",
"max_rech_amt_mean",
"max_rech_data_mean",
"monthly_2g_mean",
"monthly_3g_mean",
"night_pck_user_mean",
"offnet_mou_mean",
"og_others_mean",
"onnet_mou_mean",
"roam_ic_mou_mean",
"roam_og_mou_mean",
"sachet_2g_mean",
"sachet_3g_mean",
"spl_ic_mou_mean",
"spl_og_mou_mean",
"std_ic_mou_mean",
"std_ic_t2f_mou_mean",
"std_ic_t2m_mou_mean",
"std_ic_t2o_mou_mean",
"std_ic_t2t_mou_mean",
"std_og_mou_mean",
"std_og_t2c_mou_mean",
"std_og_t2f_mou_mean",
"std_og_t2m_mou_mean",
"std_og_t2o_mou",
"std_og_t2t_mou_mean",
"total_ic_mou_mean",
"total_og_mou_mean",
"total_rech_amt_mean",
"total_rech_data_mean",
"total_rech_num_mean",
"vol_2g_mb_mean",
"vol_3g_mb_mean"]

# %%
X_train_ = X_train[feature_names]
X_train_.head()
# Out:
#     arpu_2g_mean  arpu_3g_mean    arpu_mean  aug_vbc_3g  av_rech_amt_data_mean  count_rech_2g_mean  count_rech_3g_mean  fb_user_mean  ic_others_mean  isd_ic_mou_mean  isd_og_mou_mean  vbc_3g_mean  last_day_rch_amt_mean  loc_ic_mou_mean  loc_ic_t2f_mou_mean  loc_ic_t2m_mou_mean  loc_ic_t2o_mou  loc_ic_t2t_mou_mean  loc_og_mou_mean  loc_og_t2c_mou_mean  loc_og_t2f_mou_mean  loc_og_t2m_mou_mean  loc_og_t2o_mou  loc_og_t2t_mou_mean  max_rech_amt_mean  max_rech_data_mean  monthly_2g_mean  monthly_3g_mean  night_pck_user_mean  offnet_mou_mean  og_others_mean  onnet_mou_mean  roam_ic_mou_mean  roam_og_mou_mean  sachet_2g_mean  sachet_3g_mean  spl_ic_mou_mean  spl_og_mou_mean  std_ic_mou_mean  std_ic_t2f_mou_mean  std_ic_t2m_mou_mean  std_ic_t2o_mou_mean  std_ic_t2t_mou_mean  std_og_mou_mean  std_og_t2c_mou_mean  std_og_t2f_mou_mean  std_og_t2m_mou_mean  std_og_t2o_mou  std_og_t2t_mou_mean  total_ic_mou_mean  total_og_mou_mean  total_rech_amt_mean  total_rech_data_mean  total_rech_num_mean  
# ...

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X_train_)

# %%
y = train['churn_probability']

# %%
# %%time
clf_LR = LogisticRegression(random_state=12345)
clf_LR.fit(X,y)
# Out:
# Wall time: 1.77 s
# c:\users\lincoln.thiago.neves\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=12345)

# %% [markdown]
# ## Predict test dataset with the first ML model

# %%
test = pd.read_csv('test.csv')
test.head()
# Out:
#       id  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou last_date_of_month_6 last_date_of_month_7 last_date_of_month_8       arpu_6       arpu_7       arpu_8  onnet_mou_6  onnet_mou_7  onnet_mou_8  offnet_mou_6  offnet_mou_7  offnet_mou_8  roam_ic_mou_6  roam_ic_mou_7  roam_ic_mou_8  roam_og_mou_6  roam_og_mou_7  roam_og_mou_8  loc_og_t2t_mou_6  loc_og_t2t_mou_7  loc_og_t2t_mou_8  loc_og_t2m_mou_6  loc_og_t2m_mou_7  loc_og_t2m_mou_8  loc_og_t2f_mou_6  loc_og_t2f_mou_7  loc_og_t2f_mou_8  loc_og_t2c_mou_6  loc_og_t2c_mou_7  loc_og_t2c_mou_8  loc_og_mou_6  loc_og_mou_7  loc_og_mou_8  std_og_t2t_mou_6  std_og_t2t_mou_7  std_og_t2t_mou_8  std_og_t2m_mou_6  std_og_t2m_mou_7  std_og_t2m_mou_8  std_og_t2f_mou_6  std_og_t2f_mou_7  std_og_t2f_mou_8  std_og_t2c_mou_6  std_og_t2c_mou_7  std_og_t2c_mou_8  std_og_mou_6  std_og_mou_7  std_og_mou_8  isd_og_mou_6  isd_og_mou_7  isd_og_mou_8  spl_og_mou_6  spl_og_mou_7  spl_og_mou_8  og_others_6  og_others_7  og_others_8  total_og_mou_6  \
# ...

# %%
test1 = test.set_index('id')[features_names_LessMissing].fillna(test.median())
test1.head()
# Out:
#        onnet_mou_8  offnet_mou_8  roam_ic_mou_8  roam_og_mou_8  loc_og_t2t_mou_8  loc_og_t2m_mou_8  loc_og_t2f_mou_8  loc_og_t2c_mou_8  loc_og_mou_8  std_og_t2t_mou_8  std_og_t2m_mou_8  std_og_t2f_mou_8  std_og_t2c_mou_8  std_og_mou_8  isd_og_mou_8  spl_og_mou_8  og_others_8  loc_ic_t2t_mou_8  loc_ic_t2m_mou_8  loc_ic_t2f_mou_8  loc_ic_mou_8  std_ic_t2t_mou_8  std_ic_t2m_mou_8  std_ic_t2f_mou_8  std_ic_t2o_mou_8  std_ic_mou_8  spl_ic_mou_8  isd_ic_mou_8  ic_others_8  onnet_mou_6  offnet_mou_6  roam_ic_mou_6  roam_og_mou_6  loc_og_t2t_mou_6  loc_og_t2m_mou_6  loc_og_t2f_mou_6  loc_og_t2c_mou_6  loc_og_mou_6  std_og_t2t_mou_6  std_og_t2m_mou_6  std_og_t2f_mou_6  std_og_t2c_mou_6  std_og_mou_6  isd_og_mou_6  spl_og_mou_6  og_others_6  loc_ic_t2t_mou_6  loc_ic_t2m_mou_6  loc_ic_t2f_mou_6  loc_ic_mou_6  std_ic_t2t_mou_6  std_ic_t2m_mou_6  std_ic_t2f_mou_6  std_ic_t2o_mou_6  std_ic_mou_6  spl_ic_mou_6  isd_ic_mou_6  ic_others_6  onnet_mou_7  offnet_mou_7  roam_ic_mou_7  roam_og_mou_7  \
# ...

# %%
test2 = test.set_index('id')[features_names_BigMissing].fillna(test.mean())
test2.head()
# Out:
#        total_rech_data_6  max_rech_data_6  count_rech_2g_6  count_rech_3g_6  av_rech_amt_data_6   arpu_3g_6   arpu_2g_6  night_pck_user_6  fb_user_6  total_rech_data_7  max_rech_data_7  count_rech_2g_7  count_rech_3g_7  av_rech_amt_data_7   arpu_3g_7   arpu_2g_7  night_pck_user_7  fb_user_7  total_rech_data_8  max_rech_data_8  count_rech_2g_8  count_rech_3g_8  av_rech_amt_data_8   arpu_3g_8   arpu_2g_8  night_pck_user_8  fb_user_8
# id
# 69999         2.45497693     126.14647330       1.86315096       0.59182597        192.06800396 88.36253131 85.31891628        0.02465392 0.90995386         2.63495977     127.48845056       2.01777835       0.61718142        199.88090319 90.00624968 86.07296652        0.02063327 0.90695562         2.65097198     126.51325423       2.01691492       0.63405706        199.17870992 92.46477152 87.18317470        0.02044938 0.89194648
# ...

# %%
test_ = pd.concat([test1,test2], axis=1)
test_.head()
# Out:
#        onnet_mou_8  offnet_mou_8  roam_ic_mou_8  roam_og_mou_8  loc_og_t2t_mou_8  loc_og_t2m_mou_8  loc_og_t2f_mou_8  loc_og_t2c_mou_8  loc_og_mou_8  std_og_t2t_mou_8  std_og_t2m_mou_8  std_og_t2f_mou_8  std_og_t2c_mou_8  std_og_mou_8  isd_og_mou_8  spl_og_mou_8  og_others_8  loc_ic_t2t_mou_8  loc_ic_t2m_mou_8  loc_ic_t2f_mou_8  loc_ic_mou_8  std_ic_t2t_mou_8  std_ic_t2m_mou_8  std_ic_t2f_mou_8  std_ic_t2o_mou_8  std_ic_mou_8  spl_ic_mou_8  isd_ic_mou_8  ic_others_8  onnet_mou_6  offnet_mou_6  roam_ic_mou_6  roam_og_mou_6  loc_og_t2t_mou_6  loc_og_t2m_mou_6  loc_og_t2f_mou_6  loc_og_t2c_mou_6  loc_og_mou_6  std_og_t2t_mou_6  std_og_t2m_mou_6  std_og_t2f_mou_6  std_og_t2c_mou_6  std_og_mou_6  isd_og_mou_6  spl_og_mou_6  og_others_6  loc_ic_t2t_mou_6  loc_ic_t2m_mou_6  loc_ic_t2f_mou_6  loc_ic_mou_6  std_ic_t2t_mou_6  std_ic_t2m_mou_6  std_ic_t2f_mou_6  std_ic_t2o_mou_6  std_ic_mou_6  spl_ic_mou_6  isd_ic_mou_6  ic_others_6  onnet_mou_7  offnet_mou_7  roam_ic_mou_7  roam_og_mou_7  \
# ...

# %%
test_['arpu_2g_mean'] = (test_.arpu_2g_6 + test_.arpu_2g_7 + test_.arpu_2g_8) / 3
test_['arpu_3g_mean'] = (test_.arpu_3g_6 + test_.arpu_3g_7 + test_.arpu_3g_8) / 3
test_['arpu_mean'] = (test_.arpu_6 + test_.arpu_7 + test_.arpu_8) / 3
test_['av_rech_amt_data_mean'] = (test_.av_rech_amt_data_6 + test_.av_rech_amt_data_7 + test_.av_rech_amt_data_8) / 3
test_['count_rech_2g_mean'] = (test_.count_rech_2g_6 + test_.count_rech_2g_7 + test_.count_rech_2g_8) / 3
test_['count_rech_3g_mean'] = (test_.count_rech_3g_6 + test_.count_rech_3g_7 + test_.count_rech_3g_8) / 3
test_['fb_user_mean'] = (test_.fb_user_6 + test_.fb_user_7 + test_.fb_user_8) / 3
test_['ic_others_mean'] = (test_.ic_others_6 + test_.ic_others_7 + test_.ic_others_8) / 3
test_['isd_ic_mou_mean'] = (test_.isd_ic_mou_6 + test_.isd_ic_mou_7 + test_.isd_ic_mou_8) / 3
test_['isd_og_mou_mean'] = (test_.isd_og_mou_6 + test_.isd_og_mou_7 + test_.isd_og_mou_8) / 3
test_['vbc_3g_mean'] = (test_.jul_vbc_3g + test_.jun_vbc_3g ) / 2
test_['last_day_rch_amt_mean'] = (test_.last_day_rch_amt_6 + test_.last_day_rch_amt_7 + test_.last_day_rch_amt_8) / 3
test_['loc_ic_mou_mean'] = (test_.loc_ic_mou_6 + test_.loc_ic_mou_7 + test_.loc_ic_mou_8) / 3
test_['loc_ic_t2f_mou_mean'] = (test_.loc_ic_t2f_mou_6 + test_.loc_ic_t2f_mou_7 + test_.loc_ic_t2f_mou_8) / 3
test_['loc_ic_t2m_mou_mean'] = (test_.loc_ic_t2m_mou_6 + test_.loc_ic_t2m_mou_7 + test_.loc_ic_t2m_mou_8) / 3
test_['loc_ic_t2t_mou_mean'] = (test_.loc_ic_t2t_mou_6 + test_.loc_ic_t2t_mou_7 + test_.loc_ic_t2t_mou_8) / 3
test_['loc_og_mou_mean'] = (test_.loc_og_mou_6 + test_.loc_og_mou_7 + test_.loc_og_mou_8) / 3
test_['loc_og_t2c_mou_mean'] = (test_.loc_og_t2c_mou_6 + test_.loc_og_t2c_mou_7 + test_.loc_og_t2c_mou_8) / 3
test_['loc_og_t2f_mou_mean'] = (test_.loc_og_t2f_mou_6 + test_.loc_og_t2f_mou_7 + test_.loc_og_t2f_mou_8) / 3
test_['loc_og_t2m_mou_mean'] = (test_.loc_og_t2m_mou_6 + test_.loc_og_t2m_mou_7 + test_.loc_og_t2m_mou_8) / 3
test_['loc_og_t2t_mou_mean'] = (test_.loc_og_t2t_mou_6 + test_.loc_og_t2t_mou_7 + test_.loc_og_t2t_mou_8) / 3
test_['max_rech_amt_mean'] = (test_.max_rech_amt_6 + test_.max_rech_amt_7 + test_.max_rech_amt_8) / 3
test_['max_rech_data_mean'] = (test_.max_rech_data_6 + test_.max_rech_data_7 + test_.max_rech_data_8) / 3
test_['monthly_2g_mean'] = (test_.monthly_2g_6 + test_.monthly_2g_7 + test_.monthly_2g_8) / 3
test_['monthly_3g_mean'] = (test_.monthly_3g_6 + test_.monthly_3g_7 + test_.monthly_3g_8) / 3
test_['night_pck_user_mean'] = (test_.night_pck_user_6 + test_.night_pck_user_7 + test_.night_pck_user_8) / 3
test_['offnet_mou_mean'] = (test_.offnet_mou_6 + test_.offnet_mou_7 + test_.offnet_mou_8) / 3
test_['og_others_mean'] = (test_.og_others_6 + test_.og_others_7 + test_.og_others_8) / 3
test_['onnet_mou_mean'] = (test_.onnet_mou_6 + test_.onnet_mou_7 + test_.onnet_mou_8) / 3
test_['roam_ic_mou_mean'] = (test_.roam_ic_mou_6 + test_.roam_ic_mou_7 + test_.roam_ic_mou_8) / 3
test_['roam_og_mou_mean'] = (test_.roam_og_mou_6 + test_.roam_og_mou_7 + test_.roam_og_mou_8) / 3
test_['sachet_2g_mean'] = (test_.sachet_2g_6 + test_.sachet_2g_7 + test_.sachet_2g_8) / 3
test_['sachet_3g_mean'] = (test_.sachet_3g_6 + test_.sachet_3g_7 + test_.sachet_3g_8) / 3
test_['spl_ic_mou_mean'] = (test_.spl_ic_mou_6 + test_.spl_ic_mou_7 + test_.spl_ic_mou_8) / 3
test_['spl_og_mou_mean'] = (test_.spl_og_mou_6 + test_.spl_og_mou_7 + test_.spl_og_mou_8) / 3
test_['std_ic_mou_mean'] = (test_.std_ic_mou_6 + test_.std_ic_mou_7 + test_.std_ic_mou_8) / 3
test_['std_ic_t2f_mou_mean'] = (test_.std_ic_t2f_mou_6 + test_.std_ic_t2f_mou_7 + test_.std_ic_t2f_mou_8) / 3
test_['std_ic_t2m_mou_mean'] = (test_.std_ic_t2m_mou_6 + test_.std_ic_t2m_mou_7 + test_.std_ic_t2m_mou_8) / 3
test_['std_ic_t2o_mou_mean'] = (test_.std_ic_t2o_mou_6 + test_.std_ic_t2o_mou_7 + test_.std_ic_t2o_mou_8) / 3
test_['std_ic_t2t_mou_mean'] = (test_.std_ic_t2t_mou_6 + test_.std_ic_t2t_mou_7 + test_.std_ic_t2t_mou_8) / 3
test_['std_og_mou_mean'] = (test_.std_og_mou_6 + test_.std_og_mou_7 + test_.std_og_mou_8) / 3
test_['std_og_t2c_mou_mean'] = (test_.std_og_t2c_mou_6 + test_.std_og_t2c_mou_7 + test_.std_og_t2c_mou_8) / 3
test_['std_og_t2f_mou_mean'] = (test_.std_og_t2f_mou_6 + test_.std_og_t2f_mou_7 + test_.std_og_t2f_mou_8) / 3
test_['std_og_t2m_mou_mean'] = (test_.std_og_t2m_mou_6 + test_.std_og_t2m_mou_7 + test_.std_og_t2m_mou_8) / 3
test_['std_og_t2t_mou_mean'] = (test_.std_og_t2t_mou_6 + test_.std_og_t2t_mou_7 + test_.std_og_t2t_mou_8) / 3
test_['total_ic_mou_mean'] = (test_.total_ic_mou_6 + test_.total_ic_mou_7 + test_.total_ic_mou_8) / 3
test_['total_og_mou_mean'] = (test_.total_og_mou_6 + test_.total_og_mou_7 + test_.total_og_mou_8) / 3
test_['total_rech_amt_mean'] = (test_.total_rech_amt_6 + test_.total_rech_amt_7 + test_.total_rech_amt_8) / 3
test_['total_rech_data_mean'] = (test_.total_rech_data_6 + test_.total_rech_data_7 + test_.total_rech_data_8) / 3
test_['total_rech_num_mean'] = (test_.total_rech_num_6 + test_.total_rech_num_7 + test_.total_rech_num_8) / 3
test_['vol_2g_mb_mean'] = (test_.vol_2g_mb_6 + test_.vol_2g_mb_7 + test_.vol_2g_mb_8) / 3
test_['vol_3g_mb_mean'] = (test_.vol_3g_mb_6 + test_.vol_3g_mb_7 + test_.vol_3g_mb_8) / 3

# %%
test_.head()
# Out:
#        onnet_mou_8  offnet_mou_8  roam_ic_mou_8  roam_og_mou_8  loc_og_t2t_mou_8  loc_og_t2m_mou_8  loc_og_t2f_mou_8  loc_og_t2c_mou_8  loc_og_mou_8  std_og_t2t_mou_8  std_og_t2m_mou_8  std_og_t2f_mou_8  std_og_t2c_mou_8  std_og_mou_8  isd_og_mou_8  spl_og_mou_8  og_others_8  loc_ic_t2t_mou_8  loc_ic_t2m_mou_8  loc_ic_t2f_mou_8  loc_ic_mou_8  std_ic_t2t_mou_8  std_ic_t2m_mou_8  std_ic_t2f_mou_8  std_ic_t2o_mou_8  std_ic_mou_8  spl_ic_mou_8  isd_ic_mou_8  ic_others_8  onnet_mou_6  offnet_mou_6  roam_ic_mou_6  roam_og_mou_6  loc_og_t2t_mou_6  loc_og_t2m_mou_6  loc_og_t2f_mou_6  loc_og_t2c_mou_6  loc_og_mou_6  std_og_t2t_mou_6  std_og_t2m_mou_6  std_og_t2f_mou_6  std_og_t2c_mou_6  std_og_mou_6  isd_og_mou_6  spl_og_mou_6  og_others_6  loc_ic_t2t_mou_6  loc_ic_t2m_mou_6  loc_ic_t2f_mou_6  loc_ic_mou_6  std_ic_t2t_mou_6  std_ic_t2m_mou_6  std_ic_t2f_mou_6  std_ic_t2o_mou_6  std_ic_mou_6  spl_ic_mou_6  isd_ic_mou_6  ic_others_6  onnet_mou_7  offnet_mou_7  roam_ic_mou_7  roam_og_mou_7  \
# ...

# %%
test_2 = test_[feature_names]
test_2.head()
# Out:
#        arpu_2g_mean  arpu_3g_mean    arpu_mean   aug_vbc_3g  av_rech_amt_data_mean  count_rech_2g_mean  count_rech_3g_mean  fb_user_mean  ic_others_mean  isd_ic_mou_mean  isd_og_mou_mean  vbc_3g_mean  last_day_rch_amt_mean  loc_ic_mou_mean  loc_ic_t2f_mou_mean  loc_ic_t2m_mou_mean  loc_ic_t2o_mou  loc_ic_t2t_mou_mean  loc_og_mou_mean  loc_og_t2c_mou_mean  loc_og_t2f_mou_mean  loc_og_t2m_mou_mean  loc_og_t2o_mou  loc_og_t2t_mou_mean  max_rech_amt_mean  max_rech_data_mean  monthly_2g_mean  monthly_3g_mean  night_pck_user_mean  offnet_mou_mean  og_others_mean  onnet_mou_mean  roam_ic_mou_mean  roam_og_mou_mean  sachet_2g_mean  sachet_3g_mean  spl_ic_mou_mean  spl_og_mou_mean  std_ic_mou_mean  std_ic_t2f_mou_mean  std_ic_t2m_mou_mean  std_ic_t2o_mou_mean  std_ic_t2t_mou_mean  std_og_mou_mean  std_og_t2c_mou_mean  std_og_t2f_mou_mean  std_og_t2m_mou_mean  std_og_t2o_mou  std_og_t2t_mou_mean  total_ic_mou_mean  total_og_mou_mean  total_rech_amt_mean  total_rech_data_mean  \
# id
# ...

# %%
X_test = scaler.fit_transform(test_2)

# %%
preds_LR = clf_LR.predict(X_test)

# %%
preds_LR_ = pd.DataFrame(preds_LR, columns=['churn_probability'])

# %%
sub13_LR = pd.concat([test['id'],preds_LR_], axis=1)

# %%
sub13_LR.to_csv('sub13_LR.csv', sep=',', index=False)
